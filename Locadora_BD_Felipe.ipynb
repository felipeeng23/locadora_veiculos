# %% [markdown]
# <a href="https://colab.research.google.com/github/felipeeng23/locadora_veiculos/blob/main/Locadora_BD_Felipe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
CREATE DATABASE Locadora;
USE Locadora;

CREATE TABLE cliente(
codcliente INT PRIMARY KEY,
nome VARCHAR(50),
cidade VARCHAR(50),
sexo CHAR(1),
estado CHAR(2),
estadocivil CHAR(1)
);

CREATE TABLE marca(
codmarca INT PRIMARY KEY,
marca VARCHAR(30)
);

CREATE TABLE carro(
codcarro INT PRIMARY KEY,
codmarca INT,
modelo VARCHAR(30) NOT NULL,
valor FLOAT,
FOREIGN KEY (codmarca) REFERENCES marca (codmarca)
);

CREATE TABLE aluguel(
codaluguel INT PRIMARY KEY,
codcliente INT,
codcarro INT,
data_aluguel DATE,
FOREIGN KEY (codcliente) REFERENCES cliente (codcliente),
FOREIGN KEY (codcarro) REFERENCES carro (codcarro)
);

INSERT INTO cliente (codcliente, nome, cidade, sexo, estado, estadocivil)
VALUES
(1, 'Ana Silva', 'Duque de Caxias', 'F', 'RJ', 'C'),
(2, 'Bruna Pereira', 'Niterói', 'F', 'RJ', 'C'),
(3, 'Túlio Nascimento', 'Duque de Caxias', 'M', 'RJ', 'S'),
(4, 'Fernando Souza', 'Campinas', 'M', 'SP', 'S'),
(5, 'Lúcia Andrade', 'São Paulo', 'F', 'SP', 'C');

INSERT INTO marca (codmarca, marca) VALUES
(1, 'Ford'),
(2, 'Fiat'),
(3, 'Chevrolet'),
(4, 'Volkswagen'),
(5, 'Renault');

INSERT INTO carro (codcarro, modelo, codmarca, valor) VALUES
(1, 'Ka', 1, 100.00),
(2, 'Argo', 2, 150.00),
(3, 'Onix', 3, 170.00),
(4, 'Polo', 4, 150.00),
(5, 'Kwid', 5, 120.00);

INSERT INTO aluguel (codaluguel, codcliente, codcarro, data_aluguel)VALUES
(1, 3, 2, '2023-04-01'),
(2, 2, 1, '2023-04-02'),
(3, 2, 1, '2023-04-03'),
(4, 2, 3, '2023-04-04'),
(5, 1, 4, '2023-04-05'),
(6, 1, 4, '2023-04-13'),
(7, 1, 1, '2023-04-15'),
(8, 5, 2, '2023-04-19'),
(9, 5, 2, '2023-04-21'),
(10,3, 1, '2023-04-25');

'''
# Out:
# "\nCREATE DATABASE Locadora;\nUSE Locadora;\n\nCREATE TABLE cliente(\ncodcliente INT PRIMARY KEY,\nnome VARCHAR(50),\ncidade VARCHAR(50),\nsexo CHAR(1),\nestado CHAR(2),\nestadocivil CHAR(1)\n);\n\nCREATE TABLE marca(\ncodmarca INT PRIMARY KEY,\nmarca VARCHAR(30)\n);\n\nCREATE TABLE carro(\ncodcarro INT PRIMARY KEY,\ncodmarca INT,\nmodelo VARCHAR(30) NOT NULL,\nvalor FLOAT,\nFOREIGN KEY (codmarca) REFERENCES marca (codmarca)\n);\n\nCREATE TABLE aluguel(\ncodaluguel INT PRIMARY KEY,\ncodcliente INT,\ncodcarro INT,\ndata_aluguel DATE,\nFOREIGN KEY (codcliente) REFERENCES cliente (codcliente),\nFOREIGN KEY (codcarro) REFERENCES carro (codcarro)\n);\n\nINSERT INTO cliente (codcliente, nome, cidade, sexo, estado, estadocivil)\nVALUES\n(1, 'Ana Silva', 'Duque de Caxias', 'F', 'RJ', 'C'),\n(2, 'Bruna Pereira', 'Niterói', 'F', 'RJ', 'C'),\n(3, 'Túlio Nascimento', 'Duque de Caxias', 'M', 'RJ', 'S'),\n(4, 'Fernando Souza', 'Campinas', 'M', 'SP', 'S'),\n(5, 'Lúcia Andrade', 'São Paulo', 'F', 'S
# ...

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.0/34.0 MB 35.9 MB/s eta 0:00:00
# ...

# %%
import mysql.connector
import pandas as pd

# %%
host= '34.46.77.89' #IP público da instância
user= 'root'
password= ''
database= 'Locadora'

# %%
# !curl ipecho.net/plain
# Out:
# 34.141.246.234

# %%
def consulta(query, tabela):
  connection = mysql.connector.connect(
      host = host,
      user = user,
      password = password,
      database = database
  )
  cursor = connection.cursor()

  try:
    cursor.execute(query)
    result = cursor.fetchall()
    globals()[tabela] = pd.DataFrame(result, columns=cursor.column_names)
    display(globals()[tabela])
  finally:
    cursor.close()
    connection.close()

# %%
consulta('''
SHOW TABLES;
''','')
# Out:
#   Tables_in_Locadora
# 0            aluguel
# 1              carro
# 2            cliente
# 3              marca

# %%
consulta('''
DESCRIBE aluguel;
''','')
# Out:
#           Field  Type Null  Key Default Extra
# 0    codaluguel   int   NO  PRI    None
# 1    codcliente   int  YES  MUL    None
# 2      codcarro   int  YES  MUL    None
# 3  data_aluguel  date  YES         None

# %%
consulta('''
DESCRIBE carro;
''','')
# Out:
#       Field         Type Null  Key Default Extra
# 0  codcarro          int   NO  PRI    None
# 1  codmarca          int  YES  MUL    None
# 2    modelo  varchar(30)   NO         None
# 3     valor        float  YES         None

# %%
consulta('''
DESCRIBE cliente;
''','')
# Out:
#          Field         Type Null  Key Default Extra
# 0   codcliente          int   NO  PRI    None
# 1         nome  varchar(50)  YES         None
# 2       cidade  varchar(50)  YES         None
# 3         sexo      char(1)  YES         None
# 4       estado      char(2)  YES         None
# 5  estadocivil      char(1)  YES         None

# %%
consulta('''
DESCRIBE marca;
''','')
# Out:
#       Field         Type Null  Key Default Extra
# 0  codmarca          int   NO  PRI    None
# 1     marca  varchar(30)  YES         None

# %%
#apelidando a tabela cliente como C
consulta('''
SELECT c.nome FROM cliente AS c;
''','tabelaCliente_C')
# Out:
#                nome
# 0         Ana Silva
# 1     Bruna Pereira
# 2  Túlio Nascimento
# 3    Fernando Souza
# 4     Lúcia Andrade

# %%
consulta('''
SELECT c.modelo, m.marca FROM carro AS c
INNER JOIN marca as m
ON c.codmarca=m.codmarca
''','inner_join')
# Out:
#   modelo       marca
# 0     Ka        Ford
# 1   Argo        Fiat
# 2   Onix   Chevrolet
# 3   Polo  Volkswagen
# 4   Kwid     Renault

# %%
consulta('''
SELECT * FROM carro;
''','')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0

# %%
consulta('''
SELECT * FROM marca;
''','')
# Out:
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault

# %%
consulta('''
SELECT c.modelo, m.marca FROM carro AS c
JOIN marca as m
ON c.codmarca=m.codmarca
''','inner_join')
# Out:
#   modelo       marca
# 0     Ka        Ford
# 1   Argo        Fiat
# 2   Onix   Chevrolet
# 3   Polo  Volkswagen
# 4   Kwid     Renault

# %% [markdown]
# Selecione todos os dados da tabela cliente

# %%
consulta('''
SELECT * FROM cliente;
''','')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C

# %% [markdown]
# Liste todos os clientes que moram na cidade de "São Paulo".

# %%
consulta('''
SELECT * FROM cliente
WHERE cidade = 'São Paulo';
''','')
# Out:
#    codcliente           nome     cidade sexo estado estadocivil
# 0           5  Lúcia Andrade  São Paulo    F     SP           C

# %% [markdown]
# Liste os estados diferentes presentes na tabela cliente.

# %%
consulta('''
SELECT DISTINCT estado FROM cliente;
''','')
# Out:
#   estado
# 0     RJ
# 1     SP

# %% [markdown]
# Liste todos os clientes ordenados pelo nome em ordem alfabética.

# %%
consulta('''
SELECT * FROM cliente
ORDER BY nome ASC;
''','')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           4    Fernando Souza         Campinas    M     SP           S
# 3           5     Lúcia Andrade        São Paulo    F     SP           C
# 4           3  Túlio Nascimento  Duque de Caxias    M     RJ           S

# %% [markdown]
# Encontre todos os clientes que são do sexo feminino e solteiros.

# %%
consulta('''
SELECT * FROM cliente
WHERE sexo = 'F' AND estadocivil = 'S';
''','')
# Out:
# Empty DataFrame
# Columns: [codcliente, nome, cidade, sexo, estado, estadocivil]
# Index: []

# %% [markdown]
# Liste todos os clientes cujo nome começa com a letra 'A'.

# %%
consulta('''
SELECT * FROM cliente
WHERE nome LIKE 'A%';
''','')
# Out:
#    codcliente       nome           cidade sexo estado estadocivil
# 0           1  Ana Silva  Duque de Caxias    F     RJ           C

# %% [markdown]
# Selecione os 3 primeiros registros da tabela cliente.

# %%
consulta('''
SELECT * FROM cliente
LIMIT 3;
''','')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S

# %% [markdown]
# Liste todos os carros que são da marca 'Ford' ou 'Fiat'.

# %%
consulta('''
SELECT c.codcarro, c.modelo, m.marca, c.valor
FROM carro c
JOIN marca m ON c.codmarca = m.codmarca
WHERE m.marca IN ('Ford', 'Fiat');
''','')
# Out:
#    codcarro modelo marca  valor
# 0         1     Ka  Ford  100.0
# 1         2   Argo  Fiat  150.0

# %% [markdown]
# Encontre todos os carros cujo valor está entre 100 e 150.

# %%
consulta('''
SELECT c.codcarro, c.modelo, m.marca, c.valor
FROM carro c
JOIN marca m ON c.codmarca = m.codmarca
WHERE c.valor BETWEEN 100 AND 150;
''','')
# Out:
#    codcarro modelo       marca  valor
# 0         1     Ka        Ford  100.0
# 1         2   Argo        Fiat  150.0
# 2         4   Polo  Volkswagen  150.0
# 3         5   Kwid     Renault  120.0

# %% [markdown]
# Conte quantos aluguéis foram realizados.

# %%
consulta('''
SELECT COUNT(*) AS total_alugueis
FROM aluguel;
''','')
# Out:
#    total_alugueis
# 0              10

# %% [markdown]
# Calcule o valor total de todos os carros disponíveis para aluguel.

# %%
consulta('''
SELECT SUM(valor) AS valor_total_carros
FROM carro;
''','')
# Out:
#    valor_total_carros
# 0               690.0

# %% [markdown]
# Calcule o valor médio dos carros.

# %%
consulta('''
SELECT AVG(valor) AS valor_medio_carros
FROM carro;
''','')
# Out:
#    valor_medio_carros
# 0               138.0

# %% [markdown]
# Encontre o menor e o maior valor de aluguel de carros.

# %%
consulta('''
SELECT
    MIN(valor) AS menor_valor_aluguel,
    MAX(valor) AS maior_valor_aluguel
FROM carro;
''','')
# Out:
#    menor_valor_aluguel  maior_valor_aluguel
# 0                100.0                170.0

# %% [markdown]
# Agrupe os clientes por estado e conte quantos clientes existem em cada estado.

# %%
consulta('''
SELECT estado, COUNT(*) AS quantidade_clientes
FROM cliente
GROUP BY estado;
''','')
# Out:
#   estado  quantidade_clientes
# 0     RJ                    3
# 1     SP                    2

# %% [markdown]
# Agrupe os aluguéis por cliente e filtre apenas aqueles que fizeram mais de 2 aluguéis.

# %%
consulta('''
SELECT a.codcliente, c.nome, COUNT(*) AS total_alugueis
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
GROUP BY a.codcliente, c.nome
HAVING COUNT(*) > 2;
''','')
# Out:
#    codcliente           nome  total_alugueis
# 0           1      Ana Silva               3
# 1           2  Bruna Pereira               3

# %% [markdown]
# Liste todos os aluguéis, mostrando o nome do cliente e o modelo do carro alugado.

# %%
consulta('''
SELECT a.codaluguel, c.nome AS cliente, ca.modelo AS carro, a.data_aluguel
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
ORDER BY a.codaluguel;
''','')
# Out:
#    codaluguel           cliente carro data_aluguel
# 0           1  Túlio Nascimento  Argo   2023-04-01
# 1           2     Bruna Pereira    Ka   2023-04-02
# 2           3     Bruna Pereira    Ka   2023-04-03
# 3           4     Bruna Pereira  Onix   2023-04-04
# 4           5         Ana Silva  Polo   2023-04-05
# 5           6         Ana Silva  Polo   2023-04-13
# 6           7         Ana Silva    Ka   2023-04-15
# 7           8     Lúcia Andrade  Argo   2023-04-19
# 8           9     Lúcia Andrade  Argo   2023-04-21
# 9          10  Túlio Nascimento    Ka   2023-04-25

# %% [markdown]
# Liste todos os carros e, se houver, as informações sobre os aluguéis realizados desses carros.

# %%
consulta('''
SELECT
    ca.codcarro,
    ca.modelo,
    m.marca,
    ca.valor,
    a.codaluguel,
    c.nome AS cliente,
    a.data_aluguel
FROM carro ca
JOIN marca m ON ca.codmarca = m.codmarca
LEFT JOIN aluguel a ON ca.codcarro = a.codcarro
LEFT JOIN cliente c ON a.codcliente = c.codcliente
ORDER BY ca.codcarro, a.data_aluguel;
''','')
# Out:
#     codcarro modelo       marca  valor  codaluguel           cliente  \
# 0          1     Ka        Ford  100.0         2.0     Bruna Pereira
# 1          1     Ka        Ford  100.0         3.0     Bruna Pereira
# 2          1     Ka        Ford  100.0         7.0         Ana Silva
# 3          1     Ka        Ford  100.0        10.0  Túlio Nascimento
# 4          2   Argo        Fiat  150.0         1.0  Túlio Nascimento
# 5          2   Argo        Fiat  150.0         8.0     Lúcia Andrade
# 6          2   Argo        Fiat  150.0         9.0     Lúcia Andrade
# 7          3   Onix   Chevrolet  170.0         4.0     Bruna Pereira
# 8          4   Polo  Volkswagen  150.0         5.0         Ana Silva
# 9          4   Polo  Volkswagen  150.0         6.0         Ana Silva
# 10         5   Kwid     Renault  120.0         NaN              None
#
#    data_aluguel
# 0    2023-04-02
# 1    2023-04-03
# 2    2023-04-15
# 3    2023-04-25
# 4    2023-04-01
# 5    2023-04-19
# ...

# %% [markdown]
# Liste todos os aluguéis e as informações sobre os carros alugados, mesmo que o carro não esteja mais no banco de dados.

# %%
consulta('''
SELECT
    a.codaluguel,
    c.nome AS cliente,
    ca.codcarro,
    ca.modelo,
    m.marca,
    ca.valor,
    a.data_aluguel
FROM aluguel a
LEFT JOIN carro ca ON a.codcarro = ca.codcarro
LEFT JOIN marca m ON ca.codmarca = m.codmarca
JOIN cliente c ON a.codcliente = c.codcliente
ORDER BY a.data_aluguel;
''','')
# Out:
#    codaluguel           cliente  codcarro modelo       marca  valor  \
# 0           1  Túlio Nascimento         2   Argo        Fiat  150.0
# 1           2     Bruna Pereira         1     Ka        Ford  100.0
# 2           3     Bruna Pereira         1     Ka        Ford  100.0
# 3           4     Bruna Pereira         3   Onix   Chevrolet  170.0
# 4           5         Ana Silva         4   Polo  Volkswagen  150.0
# 5           6         Ana Silva         4   Polo  Volkswagen  150.0
# 6           7         Ana Silva         1     Ka        Ford  100.0
# 7           8     Lúcia Andrade         2   Argo        Fiat  150.0
# 8           9     Lúcia Andrade         2   Argo        Fiat  150.0
# 9          10  Túlio Nascimento         1     Ka        Ford  100.0
#
#   data_aluguel
# 0   2023-04-01
# 1   2023-04-02
# 2   2023-04-03
# 3   2023-04-04
# 4   2023-04-05
# 5   2023-04-13
# 6   2023-04-15
# 7   2023-04-19
# 8   2023-04-21
# 9   2023-04-25

# %% [markdown]
# Liste todos os clientes e os carros que alugaram, incluindo clientes que não alugaram e carros que não foram alugados.

# %%
consulta('''
SELECT
    c.codcliente,
    c.nome AS cliente,
    ca.codcarro,
    ca.modelo AS carro,
    m.marca,
    ca.valor,
    a.data_aluguel
FROM cliente c
LEFT JOIN aluguel a ON c.codcliente = a.codcliente
LEFT JOIN carro ca ON a.codcarro = ca.codcarro
LEFT JOIN marca m ON ca.codmarca = m.codmarca

UNION

SELECT
    c.codcliente,
    c.nome AS cliente,
    ca.codcarro,
    ca.modelo AS carro,
    m.marca,
    ca.valor,
    a.data_aluguel
FROM carro ca
LEFT JOIN aluguel a ON ca.codcarro = a.codcarro
LEFT JOIN cliente c ON a.codcliente = c.codcliente
LEFT JOIN marca m ON ca.codmarca = m.codmarca
ORDER BY cliente, carro;
''','')
# Out:
#     codcliente           cliente  codcarro carro       marca  valor  \
# 0          NaN              None       5.0  Kwid     Renault  120.0
# 1          1.0         Ana Silva       1.0    Ka        Ford  100.0
# 2          1.0         Ana Silva       4.0  Polo  Volkswagen  150.0
# 3          1.0         Ana Silva       4.0  Polo  Volkswagen  150.0
# 4          2.0     Bruna Pereira       1.0    Ka        Ford  100.0
# 5          2.0     Bruna Pereira       1.0    Ka        Ford  100.0
# 6          2.0     Bruna Pereira       3.0  Onix   Chevrolet  170.0
# 7          4.0    Fernando Souza       NaN  None        None    NaN
# 8          5.0     Lúcia Andrade       2.0  Argo        Fiat  150.0
# 9          5.0     Lúcia Andrade       2.0  Argo        Fiat  150.0
# 10         3.0  Túlio Nascimento       2.0  Argo        Fiat  150.0
# 11         3.0  Túlio Nascimento       1.0    Ka        Ford  100.0
#
#    data_aluguel
# 0          None
# 1    2023-04-15
# 2    2023-04-05
# ...

# %% [markdown]
# Combine os resultados de duas consultas: uma que lista clientes solteiros e outra que lista clientes casados.

# %%
consulta('''
SELECT codcliente, nome, cidade, sexo, estado, estadocivil
FROM cliente
WHERE estadocivil = 'S'

UNION

SELECT codcliente, nome, cidade, sexo, estado, estadocivil
FROM cliente
WHERE estadocivil = 'C';
''','')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 1           4    Fernando Souza         Campinas    M     SP           S
# 2           1         Ana Silva  Duque de Caxias    F     RJ           C
# 3           2     Bruna Pereira          Niterói    F     RJ           C
# 4           5     Lúcia Andrade        São Paulo    F     SP           C

# %% [markdown]
# Encontre os clientes que alugaram o carro com modelo 'Onix'.

# %%
consulta('''
SELECT DISTINCT c.codcliente, c.nome, c.cidade, c.estado
FROM aluguel a
JOIN carro ca ON a.codcarro = ca.codcarro
JOIN cliente c ON a.codcliente = c.codcliente
WHERE ca.modelo = 'Onix';
''','')
# Out:
#    codcliente           nome   cidade estado
# 0           2  Bruna Pereira  Niterói     RJ

# %% [markdown]
# Liste os modelos de carros e o número de vezes que cada um foi alugado.

# %%
consulta('''
SELECT ca.modelo, COUNT(a.codaluguel) AS total_alugueis
FROM carro ca
LEFT JOIN aluguel a ON ca.codcarro = a.codcarro
GROUP BY ca.modelo
ORDER BY total_alugueis DESC;
''','')
# Out:
#   modelo  total_alugueis
# 0     Ka               4
# 1   Argo               3
# 2   Polo               2
# 3   Onix               1
# 4   Kwid               0

# %% [markdown]
# Liste o nome dos clientes e o número de aluguéis que cada um fez.

# %%
consulta('''
SELECT c.nome AS cliente, COUNT(a.codaluguel) AS total_alugueis
FROM cliente c
LEFT JOIN aluguel a ON c.codcliente = a.codcliente
GROUP BY c.nome
ORDER BY total_alugueis DESC;
''','')
# Out:
#             cliente  total_alugueis
# 0         Ana Silva               3
# 1     Bruna Pereira               3
# 2  Túlio Nascimento               2
# 3     Lúcia Andrade               2
# 4    Fernando Souza               0

# %% [markdown]
# Crie uma consulta que retorne o nome dos clientes e uma coluna adicional chamada status_civil que classifica os clientes como "Solteiro" ou "Casado".

# %%
consulta('''
SELECT
    nome AS cliente,
    CASE
        WHEN estadocivil = 'S' THEN 'Solteiro'
        WHEN estadocivil = 'C' THEN 'Casado'
        ELSE 'Outro'
    END AS status_civil
FROM cliente;
''','')
# Out:
#             cliente status_civil
# 0         Ana Silva       Casado
# 1     Bruna Pereira       Casado
# 2  Túlio Nascimento     Solteiro
# 3    Fernando Souza     Solteiro
# 4     Lúcia Andrade       Casado

# %% [markdown]
# Liste os nomes dos clientes e as datas em que alugaram carros.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    a.data_aluguel
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
ORDER BY a.data_aluguel;
''','')
# Out:
#             cliente data_aluguel
# 0  Túlio Nascimento   2023-04-01
# 1     Bruna Pereira   2023-04-02
# 2     Bruna Pereira   2023-04-03
# 3     Bruna Pereira   2023-04-04
# 4         Ana Silva   2023-04-05
# 5         Ana Silva   2023-04-13
# 6         Ana Silva   2023-04-15
# 7     Lúcia Andrade   2023-04-19
# 8     Lúcia Andrade   2023-04-21
# 9  Túlio Nascimento   2023-04-25

# %% [markdown]
# Liste todos os modelos de carros e suas respectivas marcas.

# %%
consulta('''
SELECT
    ca.modelo,
    m.marca
FROM carro ca
JOIN marca m ON ca.codmarca = m.codmarca
ORDER BY m.marca;
''','')
# Out:
#   modelo       marca
# 0   Onix   Chevrolet
# 1   Argo        Fiat
# 2     Ka        Ford
# 3   Kwid     Renault
# 4   Polo  Volkswagen

# %% [markdown]
# Liste todos os aluguéis e os nomes dos clientes que os realizaram.

# %%
consulta('''
SELECT
    a.codaluguel,
    c.nome AS cliente,
    a.data_aluguel
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
ORDER BY a.data_aluguel;
''','')
# Out:
#    codaluguel           cliente data_aluguel
# 0           1  Túlio Nascimento   2023-04-01
# 1           2     Bruna Pereira   2023-04-02
# 2           3     Bruna Pereira   2023-04-03
# 3           4     Bruna Pereira   2023-04-04
# 4           5         Ana Silva   2023-04-05
# 5           6         Ana Silva   2023-04-13
# 6           7         Ana Silva   2023-04-15
# 7           8     Lúcia Andrade   2023-04-19
# 8           9     Lúcia Andrade   2023-04-21
# 9          10  Túlio Nascimento   2023-04-25

# %% [markdown]
# Encontre o nome dos clientes e os modelos de carros que alugaram.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    ca.modelo AS carro
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
ORDER BY c.nome;
''','')
# Out:
#             cliente carro
# 0         Ana Silva  Polo
# 1         Ana Silva  Polo
# 2         Ana Silva    Ka
# 3     Bruna Pereira    Ka
# 4     Bruna Pereira    Ka
# 5     Bruna Pereira  Onix
# 6     Lúcia Andrade  Argo
# 7     Lúcia Andrade  Argo
# 8  Túlio Nascimento  Argo
# 9  Túlio Nascimento    Ka

# %% [markdown]
# Liste todos os carros e, se houver, mostre as datas em que foram alugados.

# %%
consulta('''
SELECT
    ca.modelo AS carro,
    m.marca,
    a.data_aluguel
FROM carro ca
JOIN marca m ON ca.codmarca = m.codmarca
LEFT JOIN aluguel a ON ca.codcarro = a.codcarro
ORDER BY ca.modelo, a.data_aluguel;
''','')
# Out:
#    carro       marca data_aluguel
# 0   Argo        Fiat   2023-04-01
# 1   Argo        Fiat   2023-04-19
# 2   Argo        Fiat   2023-04-21
# 3     Ka        Ford   2023-04-02
# 4     Ka        Ford   2023-04-03
# 5     Ka        Ford   2023-04-15
# 6     Ka        Ford   2023-04-25
# 7   Kwid     Renault         None
# 8   Onix   Chevrolet   2023-04-04
# 9   Polo  Volkswagen   2023-04-05
# 10  Polo  Volkswagen   2023-04-13

# %% [markdown]
# Encontre os clientes que moram na mesma cidade e estado e que alugaram carros.

# %%
consulta('''
SELECT DISTINCT c1.nome AS cliente1, c2.nome AS cliente2, c1.cidade, c1.estado
FROM cliente c1
JOIN cliente c2 ON c1.cidade = c2.cidade AND c1.estado = c2.estado AND c1.codcliente < c2.codcliente
JOIN aluguel a1 ON c1.codcliente = a1.codcliente
JOIN aluguel a2 ON c2.codcliente = a2.codcliente;
''','')
# Out:
#     cliente1          cliente2           cidade estado
# 0  Ana Silva  Túlio Nascimento  Duque de Caxias     RJ

# %% [markdown]
# Liste os nomes dos clientes e os carros que eles alugaram, incluindo os clientes que não alugaram nenhum carro.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    ca.modelo AS carro
FROM cliente c
LEFT JOIN aluguel a ON c.codcliente = a.codcliente
LEFT JOIN carro ca ON a.codcarro = ca.codcarro
ORDER BY c.nome;
''','')
# Out:
#              cliente carro
# 0          Ana Silva  Polo
# 1          Ana Silva  Polo
# 2          Ana Silva    Ka
# 3      Bruna Pereira    Ka
# 4      Bruna Pereira    Ka
# 5      Bruna Pereira  Onix
# 6     Fernando Souza  None
# 7      Lúcia Andrade  Argo
# 8      Lúcia Andrade  Argo
# 9   Túlio Nascimento  Argo
# 10  Túlio Nascimento    Ka

# %% [markdown]
# Liste todas as marcas e, se houver, os modelos de carros associados.

# %%
consulta('''
SELECT
    m.marca,
    ca.modelo
FROM marca m
LEFT JOIN carro ca ON m.codmarca = ca.codmarca
ORDER BY m.marca;
''','')
# Out:
#         marca modelo
# 0   Chevrolet   Onix
# 1        Fiat   Argo
# 2        Ford     Ka
# 3     Renault   Kwid
# 4  Volkswagen   Polo

# %% [markdown]
# Encontre todos os aluguéis e o estado civil dos clientes que alugaram os carros.

# %%
consulta('''
SELECT
    a.codaluguel,
    c.nome AS cliente,
    CASE
        WHEN c.estadocivil = 'S' THEN 'Solteiro'
        WHEN c.estadocivil = 'C' THEN 'Casado'
        ELSE 'Outro'
    END AS estado_civil,
    a.data_aluguel
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
ORDER BY a.data_aluguel;
''','')
# Out:
#    codaluguel           cliente estado_civil data_aluguel
# 0           1  Túlio Nascimento     Solteiro   2023-04-01
# 1           2     Bruna Pereira       Casado   2023-04-02
# 2           3     Bruna Pereira       Casado   2023-04-03
# 3           4     Bruna Pereira       Casado   2023-04-04
# 4           5         Ana Silva       Casado   2023-04-05
# 5           6         Ana Silva       Casado   2023-04-13
# 6           7         Ana Silva       Casado   2023-04-15
# 7           8     Lúcia Andrade       Casado   2023-04-19
# 8           9     Lúcia Andrade       Casado   2023-04-21
# 9          10  Túlio Nascimento     Solteiro   2023-04-25

# %% [markdown]
# Liste os clientes e as cidades em que moram para aqueles que alugaram carros.

# %%
consulta('''
SELECT DISTINCT
    c.nome AS cliente,
    c.cidade
FROM cliente c
JOIN aluguel a ON c.codcliente = a.codcliente
ORDER BY c.cidade, c.nome;
''','')
# Out:
#             cliente           cidade
# 0         Ana Silva  Duque de Caxias
# 1  Túlio Nascimento  Duque de Caxias
# 2     Bruna Pereira          Niterói
# 3     Lúcia Andrade        São Paulo

# %% [markdown]
# Liste os clientes que alugaram carros e os modelos de carros que eles alugaram, incluindo a marca do carro.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    ca.modelo AS carro,
    m.marca
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
JOIN marca m ON ca.codmarca = m.codmarca
ORDER BY c.nome, ca.modelo;
''','')
# Out:
#             cliente carro       marca
# 0         Ana Silva    Ka        Ford
# 1         Ana Silva  Polo  Volkswagen
# 2         Ana Silva  Polo  Volkswagen
# 3     Bruna Pereira    Ka        Ford
# 4     Bruna Pereira    Ka        Ford
# 5     Bruna Pereira  Onix   Chevrolet
# 6     Lúcia Andrade  Argo        Fiat
# 7     Lúcia Andrade  Argo        Fiat
# 8  Túlio Nascimento  Argo        Fiat
# 9  Túlio Nascimento    Ka        Ford

# %% [markdown]
# Encontre todos os aluguéis realizados em uma cidade específica e liste os nomes dos clientes e os modelos de carros alugados.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    c.cidade,
    ca.modelo AS carro
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
WHERE c.cidade = 'Niterói' -- Substitua 'Niterói' pela cidade desejada
ORDER BY c.nome, ca.modelo;
''','')
# Out:
#          cliente   cidade carro
# 0  Bruna Pereira  Niterói    Ka
# 1  Bruna Pereira  Niterói    Ka
# 2  Bruna Pereira  Niterói  Onix

# %% [markdown]
# Liste os modelos de carros e a quantidade de vezes que foram alugados.

# %%
consulta('''
SELECT
    ca.modelo AS carro,
    COUNT(a.codaluguel) AS total_alugueis
FROM carro ca
LEFT JOIN aluguel a ON ca.codcarro = a.codcarro
GROUP BY ca.modelo
ORDER BY total_alugueis DESC;
''','')
# Out:
#   carro  total_alugueis
# 0    Ka               4
# 1  Argo               3
# 2  Polo               2
# 3  Onix               1
# 4  Kwid               0

# %% [markdown]
# Encontre os clientes que alugaram mais de um carro.

# %%
consulta('''
SELECT
    c.codcliente,
    c.nome AS cliente,
    COUNT(DISTINCT a.codcarro) AS total_modelos_alugados
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
GROUP BY c.codcliente, c.nome
HAVING COUNT(DISTINCT a.codcarro) > 1
ORDER BY total_modelos_alugados DESC;
''','')
# Out:
#    codcliente           cliente  total_modelos_alugados
# 0           1         Ana Silva                       2
# 1           2     Bruna Pereira                       2
# 2           3  Túlio Nascimento                       2

# %% [markdown]
# Liste os clientes, as datas de aluguel e o valor do carro alugado.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    a.data_aluguel,
    ca.valor AS valor_carro
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
ORDER BY a.data_aluguel;
''','')
# Out:
#             cliente data_aluguel  valor_carro
# 0  Túlio Nascimento   2023-04-01        150.0
# 1     Bruna Pereira   2023-04-02        100.0
# 2     Bruna Pereira   2023-04-03        100.0
# 3     Bruna Pereira   2023-04-04        170.0
# 4         Ana Silva   2023-04-05        150.0
# 5         Ana Silva   2023-04-13        150.0
# 6         Ana Silva   2023-04-15        100.0
# 7     Lúcia Andrade   2023-04-19        150.0
# 8     Lúcia Andrade   2023-04-21        150.0
# 9  Túlio Nascimento   2023-04-25        100.0

# %% [markdown]
# Liste os modelos de carros que nunca foram alugados.

# %%
consulta('''
SELECT ca.modelo
FROM carro ca
LEFT JOIN aluguel a ON ca.codcarro = a.codcarro
WHERE a.codaluguel IS NULL;
''','')
# Out:
#   modelo
# 0   Kwid

# %% [markdown]
# Encontre os clientes que alugaram carros e o total gasto em aluguéis.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    SUM(ca.valor) AS total_gasto
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
GROUP BY c.nome
ORDER BY total_gasto DESC;
''','')
# Out:
#             cliente  total_gasto
# 0         Ana Silva        400.0
# 1     Bruna Pereira        370.0
# 2     Lúcia Andrade        300.0
# 3  Túlio Nascimento        250.0

# %% [markdown]
# Liste as marcas de carros e o número total de aluguéis por marca.

# %%
consulta('''
SELECT
    m.marca,
    COUNT(a.codaluguel) AS total_alugueis
FROM marca m
JOIN carro ca ON m.codmarca = ca.codmarca
LEFT JOIN aluguel a ON ca.codcarro = a.codcarro
GROUP BY m.marca
ORDER BY total_alugueis DESC;
''','')
# Out:
#         marca  total_alugueis
# 0        Ford               4
# 1        Fiat               3
# 2  Volkswagen               2
# 3   Chevrolet               1
# 4     Renault               0

# %% [markdown]
# Encontre os clientes que alugaram carros em um determinado mês e ano, listando os modelos de carros e as datas de aluguel.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    ca.modelo AS carro,
    a.data_aluguel
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
WHERE MONTH(a.data_aluguel) = 4 -- Substitua pelo mês desejado
AND YEAR(a.data_aluguel) = 2023 -- Substitua pelo ano desejado
ORDER BY a.data_aluguel;
''','')
# Out:
#             cliente carro data_aluguel
# 0  Túlio Nascimento  Argo   2023-04-01
# 1     Bruna Pereira    Ka   2023-04-02
# 2     Bruna Pereira    Ka   2023-04-03
# 3     Bruna Pereira  Onix   2023-04-04
# 4         Ana Silva  Polo   2023-04-05
# 5         Ana Silva  Polo   2023-04-13
# 6         Ana Silva    Ka   2023-04-15
# 7     Lúcia Andrade  Argo   2023-04-19
# 8     Lúcia Andrade  Argo   2023-04-21
# 9  Túlio Nascimento    Ka   2023-04-25

# %% [markdown]
# Liste os clientes que moram em estados diferentes e que alugaram carros, junto com os modelos alugados.

# %%
consulta('''
SELECT DISTINCT
    c1.nome AS cliente1,
    c1.estado AS estado1,
    c2.nome AS cliente2,
    c2.estado AS estado2,
    ca.modelo AS carro
FROM aluguel a1
JOIN cliente c1 ON a1.codcliente = c1.codcliente
JOIN aluguel a2 ON a1.codcarro = a2.codcarro
JOIN cliente c2 ON a2.codcliente = c2.codcliente AND c1.codcliente <> c2.codcliente
JOIN carro ca ON a1.codcarro = ca.codcarro
WHERE c1.estado <> c2.estado
ORDER BY ca.modelo, c1.estado;
''','')
# Out:
#            cliente1 estado1          cliente2 estado2 carro
# 0  Túlio Nascimento      RJ     Lúcia Andrade      SP  Argo
# 1     Lúcia Andrade      SP  Túlio Nascimento      RJ  Argo

# %% [markdown]
# Encontre os clientes que alugaram carros, os modelos de carros alugados, as marcas desses carros e as datas de aluguel, ordenando pelos nomes dos clientes.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    ca.modelo AS carro,
    m.marca,
    a.data_aluguel
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
JOIN marca m ON ca.codmarca = m.codmarca
ORDER BY c.nome, a.data_aluguel;
''','')
# Out:
#             cliente carro       marca data_aluguel
# 0         Ana Silva  Polo  Volkswagen   2023-04-05
# 1         Ana Silva  Polo  Volkswagen   2023-04-13
# 2         Ana Silva    Ka        Ford   2023-04-15
# 3     Bruna Pereira    Ka        Ford   2023-04-02
# 4     Bruna Pereira    Ka        Ford   2023-04-03
# 5     Bruna Pereira  Onix   Chevrolet   2023-04-04
# 6     Lúcia Andrade  Argo        Fiat   2023-04-19
# 7     Lúcia Andrade  Argo        Fiat   2023-04-21
# 8  Túlio Nascimento  Argo        Fiat   2023-04-01
# 9  Túlio Nascimento    Ka        Ford   2023-04-25

# %% [markdown]
# Liste os clientes que alugaram carros mais de uma vez e os detalhes dos carros que alugaram.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    ca.modelo AS carro,
    m.marca,
    ca.valor AS valor_aluguel,
    a.data_aluguel
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
JOIN marca m ON ca.codmarca = m.codmarca
WHERE c.codcliente IN (
    SELECT codcliente
    FROM aluguel
    GROUP BY codcliente
    HAVING COUNT(*) > 1
)
ORDER BY c.nome, a.data_aluguel;
''','')
# Out:
#             cliente carro       marca  valor_aluguel data_aluguel
# 0         Ana Silva  Polo  Volkswagen          150.0   2023-04-05
# 1         Ana Silva  Polo  Volkswagen          150.0   2023-04-13
# 2         Ana Silva    Ka        Ford          100.0   2023-04-15
# 3     Bruna Pereira    Ka        Ford          100.0   2023-04-02
# 4     Bruna Pereira    Ka        Ford          100.0   2023-04-03
# 5     Bruna Pereira  Onix   Chevrolet          170.0   2023-04-04
# 6     Lúcia Andrade  Argo        Fiat          150.0   2023-04-19
# 7     Lúcia Andrade  Argo        Fiat          150.0   2023-04-21
# 8  Túlio Nascimento  Argo        Fiat          150.0   2023-04-01
# 9  Túlio Nascimento    Ka        Ford          100.0   2023-04-25

# %% [markdown]
# Encontre os modelos de carros que foram alugados por clientes de cidades específicas e liste as marcas desses carros.

# %%
consulta('''
SELECT DISTINCT
    ca.modelo AS carro,
    m.marca,
    c.cidade
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
JOIN marca m ON ca.codmarca = m.codmarca
WHERE c.cidade IN ('Niterói', 'São Paulo') -- Substitua pelas cidades desejadas
ORDER BY c.cidade, ca.modelo;
''','')
# Out:
#   carro      marca     cidade
# 0    Ka       Ford    Niterói
# 1  Onix  Chevrolet    Niterói
# 2  Argo       Fiat  São Paulo

# %% [markdown]
# Liste os clientes que alugaram carros, os modelos e as marcas dos carros, e o total gasto em aluguéis, agrupado por cliente.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    GROUP_CONCAT(DISTINCT ca.modelo ORDER BY ca.modelo SEPARATOR ', ') AS modelos_alugados,
    GROUP_CONCAT(DISTINCT m.marca ORDER BY m.marca SEPARATOR ', ') AS marcas_alugadas,
    SUM(ca.valor) AS total_gasto
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
JOIN marca m ON ca.codmarca = m.codmarca
GROUP BY c.nome
ORDER BY total_gasto DESC;
''','')
# Out:
#             cliente modelos_alugados   marcas_alugadas  total_gasto
# 0         Ana Silva         Ka, Polo  Ford, Volkswagen        400.0
# 1     Bruna Pereira         Ka, Onix   Chevrolet, Ford        370.0
# 2     Lúcia Andrade             Argo              Fiat        300.0
# 3  Túlio Nascimento         Argo, Ka        Fiat, Ford        250.0

# %% [markdown]
# Encontre os carros que foram alugados nos últimos 30 dias e os clientes que os alugaram.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    ca.modelo AS carro,
    m.marca,
    a.data_aluguel
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
JOIN marca m ON ca.codmarca = m.codmarca
WHERE a.data_aluguel >= DATE_SUB(NOW(), INTERVAL 30 DAY)
ORDER BY a.data_aluguel DESC;
''','')
# Out:
# Empty DataFrame
# Columns: [cliente, carro, marca, data_aluguel]
# Index: []

# %% [markdown]
# Liste os clientes, os carros que alugaram, as marcas desses carros, e o valor total gasto em aluguéis, filtrando por um intervalo de datas específico.

# %%
consulta('''
SELECT
    c.nome AS cliente,
    GROUP_CONCAT(DISTINCT ca.modelo ORDER BY ca.modelo SEPARATOR ', ') AS modelos_alugados,
    GROUP_CONCAT(DISTINCT m.marca ORDER BY m.marca SEPARATOR ', ') AS marcas_alugadas,
    SUM(ca.valor) AS total_gasto
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro ca ON a.codcarro = ca.codcarro
JOIN marca m ON ca.codmarca = m.codmarca
WHERE a.data_aluguel BETWEEN '2023-04-01' AND '2023-04-15' -- Defina o intervalo desejado
GROUP BY c.nome
ORDER BY total_gasto DESC;
''','')
# Out:
#             cliente modelos_alugados   marcas_alugadas  total_gasto
# 0         Ana Silva         Ka, Polo  Ford, Volkswagen        400.0
# 1     Bruna Pereira         Ka, Onix   Chevrolet, Ford        370.0
# 2  Túlio Nascimento             Argo              Fiat        150.0
